# %%
a = 100
b = 10.5
c = "Python"
d = True
e = 4+5j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
a = 20
b = 3
print("Addition:",a+b)
print("Substration:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor Division:",a//b)
print("Modulas:",a%b)
# Out:
# Addition: 23
# Substration: 17
# Multiplication: 60
# Division: 6.666666666666667
# Floor Division: 6
# Modulas: 2

# %%
a = 15
b = 20
print("Greater than:",a>b)
print("Less than:",a<b)
print("Greater tha equals to:",a>=b)
print("Less tha equals to:",a<=b)
print("Equals to:",a==b)
print("Not equals:",a!=b)
# Out:
# Greater than: False
# Less than: True
# Greater tha equals to: False
# Less tha equals to: True
# Equals to: False
# Not equals: True

# %%
name1 = "Python"
name2 = "python"

name1==name2
# Out:
# False

# %%
L1 = ["Apple", "Banana", "Mango", "Orange", "Grapes"]
print(L1)
print(type(L1))
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']
# <class 'list'>

# %%
L1[0]
# Out:
# 'Apple'

# %%
L1[-1]
# Out:
# 'Grapes'

# %%
L1[2]
# Out:
# 'Mango'

# %%
L1 = ["Apple", "Banana", "Mango", "Orange", "Grapes"]
print("Before Append:",L1)
L1.append("Pineapple")
print("After Append:",L1)
# Out:
# Before Append: ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']
# After Append: ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes', 'Pineapple']

# %%
L1 = ["Apple", "Banana", "Mango", "Orange", "Grapes"]
print("Before indexing:",L1)
L1.insert(1,"Watermelon")
print("After indexing:",L1)
# Out:
# Before indexing: ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']
# After indexing: ['Apple', 'Watermelon', 'Banana', 'Mango', 'Orange', 'Grapes']

# %%
L1 = ["Apple", "Banana", "Mango", "Orange", "Grapes"]
print("Before removing:",L1)
L1.remove("Banana")
print("After removing:",L1)
# Out:
# Before removing: ['Apple', 'Banana', 'Mango', 'Orange', 'Grapes']
# After removing: ['Apple', 'Mango', 'Orange', 'Grapes']

# %%
L1 = [50, 20, 80, 10, 40]
print("Before sort:",L1)
L1.sort()
print("After sort asc:",L1)
L1.sort(reverse=True)
print("After sort desc:",L1)
# Out:
# Before sort: [50, 20, 80, 10, 40]
# After sort asc: [10, 20, 40, 50, 80]
# After sort desc: [80, 50, 40, 20, 10]

# %%
tup= ("Red", "Blue", "Green", "Black")
print(tup)
tup[0]
# Out:
# ('Red', 'Blue', 'Green', 'Black')
# 'Red'

# %%
tup[1]
# Out:
# 'Blue'

# %%
tup[2]
# Out:
# 'Green'

# %%
tup[3]
# Out:
# 'Black'

# %%
tup= ("Red", "Blue", "Green", "Black")
tup.index("Green")
# Out:
# 2

# %%
L1= (10, 20, 10, 30, 10)
tup.count(10)
# Out:
# 0

# %%
dict1={ "Name" : "Roja",
        "City" : "Srikakulam",
        "Age"  :30
      }
print (dict1,type(dict1))
# Out:
# {'Name': 'Roja', 'City': 'Srikakulam', 'Age': 30} <class 'dict'>

# %%
dict1.values()
# Out:
# dict_values(['Roja', 'Srikakulam', 30])

# %%
dict2={
        "Salary" : 50000
       }
dict1.update(dict2)

# %%
print(dict1)
# Out:
# {'Name': 'Roja', 'City': 'Srikakulam', 'Age': 30, 'Salary': 50000}

# %%
dict1={ "Name" : "Roja",
        "City" : "Srikakulam",
        "Age"  :30
      }

# %%
dict1["Age"]=22

# %%
print(dict1)
# Out:
# {'Name': 'Roja', 'City': 'Srikakulam', 'Age': 22}

# %%
dict1.pop("City")
# Out:
# 'Srikakulam'

# %%
print(dict1)
# Out:
# {'Name': 'Roja', 'Age': 22}

# %%
dict1.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
dict1.values()
# Out:
# dict_values(['Roja', 22])

# %%
L1 = [10, 20, 30]
L2 = [40, 50, 60]
print(L1)
print(L2)
L1.extend(L2)
print("After append:",L1)
# Out:
# [10, 20, 30]
# [40, 50, 60]
# After append: [10, 20, 30, 40, 50, 60]

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

dict1.update(dict2)
print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
name = "Roja"
age = 22
salary = 30000.0
is_python_easy = True

print("Name:", name)
print("Age:", age)
print("Salary:", salary)
print("Is Python Easy?", is_python_easy)
# Out:
# Name: Roja
# Age: 22
# Salary: 30000.0
# Is Python Easy? True
